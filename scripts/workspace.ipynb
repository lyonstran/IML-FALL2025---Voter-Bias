# %%
import pandas as pd
import numpy as np
import requests
import time
from bs4 import BeautifulSoup

# %%
newest = pd.read_csv(r'C:\Users\Lyons\OneDrive\Desktop\IML-FALL2025---Voter-Bias\voter_team.csv')
original = pd.read_csv(r'C:\Users\Lyons\OneDrive\Desktop\IML-FALL2025---Voter-Bias\results\cfb\output_data\voter_team.csv')
corrected = pd.read_csv(r'C:\Users\Lyons\OneDrive\Desktop\IML-FALL2025---Voter-Bias\results\cfb\output_data\voter_team_corrected.csv')
mb = pd.read_csv(r'C:\Users\Lyons\OneDrive\Desktop\IML-FALL2025---Voter-Bias\results\cfb\original_data\master_bias.csv')

# %%
print('CORECTED n column SUM: ', corrected.n.sum(), '\n'
      'newest n column SUM: ', newest.n.sum(), '\n',
      'original n column SUM: ', original.n.sum(), '\n', 
        'master bias # of rows: ', len(mb))
# Out:
# CORECTED n column SUM:  255498
# newest n column SUM:  32952
#  original n column SUM:  32952
#  master bias # of rows:  255498
