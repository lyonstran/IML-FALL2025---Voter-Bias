# %%
import pandas as pd
import numpy as np
import requests
import time
from bs4 import BeautifulSoup

# %%
voter_team = pd.read_csv(r'C:\Users\Lyons\OneDrive\Desktop\IML-FALL2025---Voter-Bias\voter_team.csv')
mb = pd.read_csv(r'C:\Users\Lyons\OneDrive\Desktop\IML-FALL2025---Voter-Bias\results\cfb\original_data\master_bias.csv')

# %%
print('voter team n column: ', voter_team.n.sum(), ', master bias # of rows: ', len(mb))
# Out:
# voter team n column:  255498 , master bias # of rows:  255498
